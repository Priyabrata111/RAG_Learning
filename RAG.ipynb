# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 2.8 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.9 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 3.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.5 MB 3.4 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 3.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 2.8 MB/s eta 0:00:01
# ...

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Priyabrata Mondal",
        "date_created":"2025-02-27"
    }
)
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Priyabrata Mondal', 'date_created': '2025-02-27'}, page_content='this is the main text content I am using to create RAG')
